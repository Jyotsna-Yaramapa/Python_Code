# %% [markdown]
# Use Case 1: Division Safe Calculator
#  Ask the user for two numbers.
#  Perform division and print the result.
#  If the user tries to divide by 0, print:
#  "Error: Division by zero is not allowed."""

# %%
from numpy import exceptions

try:
    a=int(input("Enter the first number:"))
    b=int(input("Enter the second number:"))
    c=a/b
    print(f"Result:{c}")
except ZeroDivisionError as err:
    print(f"Not a valid Error is : {err} ")
# Out:
# Not a valid Error is : division by zero

# %% [markdown]
# Use Case 2: Safe Integer Input
# Ask the user to enter a number.
# Try converting it to an integer.
# If conversion fails, print:
# "Invalid input. Please enter a numeric value."

# %%
try:
    a=input("Enter the number:")
    print(int(a))
except ValueError as err:
    print(err)
# Out:
# -10
